# %%
import pandas as pd

# %%
data = pd.read_csv("price.csv")
data.columns
# Out:
# Index(['customer_id', 'month', 'plan_name', 'data_limit_gb', 'data_used_gb',
#        'text_messages_sent', 'call_minutes_used', 'monthly_price_GBP',
#        'overage_charges_GBP', 'tenure_years', 'plan_duration_years',
#        'satisfaction_score'],
#       dtype='object')

# %%
mod = pd.read_csv("mod1.csv")
mod.columns
# Out:
# Index(['customer_id', 'customer_name', 'uk_contact_number', 'email', 'month',
#        'plan_name', 'data_limit_gb', 'data_used_gb', 'text_messages_sent',
#        'call_minutes_used', 'monthly_price_GBP', 'overage_charges_GBP',
#        'tenure_years', 'plan_duration_years', 'satisfaction_score'],
#       dtype='object')

# %%
d1 = pd.read_csv("mod2.csv")
d2 = pd.read_csv("bill2.csv")

# %%
d1.columns
# Out:
# Index(['invoice_id', 'customer_id', 'customer_name', 'uk_contact_number',
#        'email', 'month', 'plan_name', 'base_plan_charge_GBP', 'data_used_gb',
#        'overage_charges_expected_GBP', 'overage_charges_billed_GBP', 'tax_GBP',
#        'invoice_total_GBP', 'payment_received_GBP', 'payment_status',
#        'reconciliation_match_score', 'billing_anomaly_flag',
#        'dispute_description', 'dispute_type'],
#       dtype='object')

# %%
d2.columns
# Out:
# Index(['invoice_id', 'customer_id', 'month', 'plan_name',
#        'base_plan_charge_GBP', 'data_used_gb', 'overage_charges_expected_GBP',
#        'overage_charges_billed_GBP', 'tax_GBP', 'invoice_total_GBP',
#        'payment_received_GBP', 'payment_status', 'reconciliation_match_score',
#        'billing_anomaly_flag', 'dispute_description', 'dispute_type'],
#       dtype='object')
